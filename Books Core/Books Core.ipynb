# %% [markdown]
# ## ![Books%20PNG.png](attachment:Books%20PNG.png)

# %%
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists

connection_str = "mysql+pymysql://root:root@localhost/new_db2"

# %%
engine3 = create_engine(connection_str)

# %%
create_database(connection_str)

# %%
database_exists(connection_str)
# Out:
# True

# %%
connection = "mysql+pymysql://root:root@localhost/books"

# %%
import pandas as pd
users_df = pd.read_csv('user_data.csv')
users_df.head()
# Out:
#    id first_name  last_name                 email
# 0   1       John        Doe          JD@books.com
# 1   2      Robin      Smith       Robin@books.com
# 2   3     Gloria  Rodriguez  grodriquez@books.com

# %%
authors_df = pd.read_csv('authors_data.csv')
authors_df.head()
# Out:
#    id        author_name
# 0   1       Stephen King
# 1   2  F.Scott Fitgerald
# 2   3        Jack London
# 3   4        Jane Austen
# 4   5       Mary Shelley

# %%
books_df = pd.read_csv('books_data.csv')
books_df.head()
# Out:
#    id                 title  author_id
# 0   1           The Shining          1
# 1   2                    It          1
# 2   3      The Great Gatsby          2
# 3   4  The Call of the Wild          3
# 4   5   Pride and Prejudice          4

# %%
favorites_df = pd.read_csv('favorites_data.csv')
favorites_df.head()
# Out:
#    user_id  book_id
# 0        1        1
# 1        1        2
# 2        1        3
# 3        2        4
# 4        2        5

# %%
sql = """
SELECT books_data.title, favorites_data.user_id
FROM books_data
JOIN favorites_data ON books_data.id = favorites_data.book_id
WHERE favorites_data.user_id = 
    (SELECT user_data.id FROM user_data WHERE (user_data.last_name = "Doe" AND user_data.first_name = "John"));
"""
pd.read_sql_query(sql, engine3)
# Out:
#               title  user_id
# 0       The Shining        1
# 1                It        1
# 2  The Great Gatsby        1
